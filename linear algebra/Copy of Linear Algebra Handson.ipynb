# %% [markdown]
# 🎉 Good Evening, Everyone!
#
#
# I hope you're all doing great and having a wonderful start to your day!
#
# Welcome to today’s session — we’re excited to have you here.
#
# Today’s Agenda: Linear Algebra – Hands-on Session! ✍️📐
# Get ready to dive into some exciting and practical concepts! 💡📊
#
# Let’s wait for a few more minutes while everyone joins in.
# Meanwhile, get your setup ready! 💬

# %% [markdown]
# #matrix
# #matrix operations
# #transpose
# #det
# #adj,inverse
# #rank
# #eigen values and vectors

# %%
#create a matrix

import numpy as np

A = np.array([[1,2],[3,4]])
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A +2
# Out:
# array([[3, 4],
#        [5, 6]])

# %%
A-2
# Out:
# array([[-1,  0],
#        [ 1,  2]])

# %%
A/2
# Out:
# array([[0.5, 1. ],
#        [1.5, 2. ]])

# %%
A*2
# Out:
# array([[2, 4],
#        [6, 8]])

# %%
B = np.array([[5,6],[7,8]])

# %%
A+B
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %%
A-B
# Out:
# array([[-4, -4],
#        [-4, -4]])

# %%
A*B
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
A/B
# Out:
# array([[0.2       , 0.33333333],
#        [0.42857143, 0.5       ]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
C = np.array([[1,2],[4,5],[8,9]])
C
# Out:
# array([[1, 2],
#        [4, 5],
#        [8, 9]])

# %%
A*C
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2110729729.py in <cell line: 0>()
# ----> 1 A*C
#
# ValueError: operands could not be broadcast together with shapes (2,2) (3,2)

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#transpose
A.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
A = np.array([[1,2,30],[4,5,6],[8,9,10]])
A
# Out:
# array([[ 1,  2, 30],
#        [ 4,  5,  6],
#        [ 8,  9, 10]])

# %%
#det
np.linalg.det(A)
# Out:
# np.float64(-108.00000000000003)

# %%
#inv
x = np.linalg.inv(A)
x
# Out:
# array([[ 0.03703704, -2.31481481,  1.27777778],
#        [-0.07407407,  2.12962963, -1.05555556],
#        [ 0.03703704, -0.06481481,  0.02777778]])

# %%
y = np.round(x, 2)
y
# Out:
# array([[ 0.04, -2.31,  1.28],
#        [-0.07,  2.13, -1.06],
#        [ 0.04, -0.06,  0.03]])

# %%
y = np.rint(x).astype(int)
y
# Out:
# array([[ 0, -2,  1],
#        [ 0,  2, -1],
#        [ 0,  0,  0]])

# %%
#rank

A
# Out:
# array([[ 1,  2, 30],
#        [ 4,  5,  6],
#        [ 8,  9, 10]])

# %%
np.linalg.matrix_rank(A)
# Out:
# np.int64(3)

# %%
A
# Out:
# array([[ 1,  2, 30],
#        [ 4,  5,  6],
#        [ 8,  9, 10]])

# %%
B = np.array([[1,2,3],[4,5,6]])
B.shape
# Out:
# (2, 3)

# %%
np.linalg.matrix_rank(B)
# Out:
# np.int64(2)

# %%
A
# Out:
# array([[ 1,  2, 30],
#        [ 4,  5,  6],
#        [ 8,  9, 10]])

# %%
eig_val, eig_vec = np.linalg.eig(B)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /tmp/ipython-input-4013389220.py in <cell line: 0>()
# ----> 1 eig_val, eig_vec = np.linalg.eig(B)
#
# /usr/local/lib/python3.12/dist-packages/numpy/linalg/_linalg.py in eig(a)
#    1436     a, wrap = _makearray(a)
#    1437     _assert_stacked_2d(a)
# -> 1438     _assert_stacked_square(a)
#    1439     _assert_finite(a)
#    1440     t, result_t = _commonType(a)
#
# /usr/local/lib/python3.12/dist-packages/numpy/linalg/_linalg.py in _assert_stacked_square(*arrays)
#     200         m, n = a.shape[-2:]
#     201         if m != n:
# --> 202             raise LinAlgError('Last 2 dimensions of the array must be square')
#     203
#     204 def _assert_finite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
eig_val
# Out:
# array([25.2255224 , -9.66834663,  0.44282423])

# %%
eig_vec
# Out:
# array([[-0.74730261, -0.93763801,  0.72993389],
#        [-0.32047526,  0.12264509, -0.68277009],
#        [-0.58209485,  0.32525857,  0.03196129]])

# %%
A
# Out:
# array([[ 1,  2, 30],
#        [ 4,  5,  6],
#        [ 8,  9, 10]])

# %%
A*A
# Out:
# array([[  1,   4, 900],
#        [ 16,  25,  36],
#        [ 64,  81, 100]])

# %%
from numpy.linalg import matrix_power

# %%
matrix_power(A, 2)
# Out:
# array([[249, 282, 342],
#        [ 72,  87, 210],
#        [124, 151, 394]])

# %%
A = np.array([[1,2],[3,4]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A*A
# Out:
# array([[ 1,  4],
#        [ 9, 16]])

# %%
matrix_power(A, 2)
# Out:
# array([[ 7, 10],
#        [15, 22]])
