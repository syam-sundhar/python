# %%
import numpy # it it executed without any error --> its already available in your machine

# %%
import xyz # xyz is random word --> so it will throw error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import xyz
#
# ModuleNotFoundError: No module named 'xyz'

# %%
import Numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import Numpy
#
# ModuleNotFoundError: No module named 'Numpy'

# %%
import numppy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import numppy
#
# ModuleNotFoundError: No module named 'numppy'

# %%
ModuleNotFoundError
1. Case sensitive
2. Spelling mistake
3. Install your module --> pypi
# Out:
# ModuleNotFoundError

# %%
# how to install module if its not available in machine (modulenotfound error)

# %%
pip install numpy # ! it does the installation via terminal
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Numpy

# %%
# convert list/tuple into an array

# %%
ar1 = numpy.array([1,2,3,4,5])
ar1
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(ar1) # data structure for ar1 --> array
# Out:
# numpy.ndarray

# %%
numpy.array([1,2.4,'a']) # everything will be converted to higher data type
# U--> uni coded string # strings in numpy
# Out:
# array(['1', '2.4', 'a'], dtype='<U32')

# %%
bool --> int --> float --> complex --> str

# %%
numpy.array([1,2.4,2,3,4,5,6,7,8])
# Out:
# array([1. , 2.4, 2. , 3. , 4. , 5. , 6. , 7. , 8. ])

# %%
list1 = [1,2,3,4,5]
[i**2 for i in list1]
# Out:
# [1, 4, 9, 16, 25]

# %%
ar1**2
# Out:
# array([ 1,  4,  9, 16, 25])
