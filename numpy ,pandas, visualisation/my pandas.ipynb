# %%
import pandas as pd

# %%
sr1=pd.Series([1,3,2,5,9,6])
sr1
# Out:
# 0    1
# 1    3
# 2    2
# 3    5
# 4    9
# 5    6
# dtype: int64

# %%
type(sr1)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### syam

# %% [markdown]
# # syam

# %% [markdown]
# ## syam

# %% [markdown]
# ### syam

# %%
df1=pd.DataFrame({'id':[1,2,3,4],'start_marks':[98,81,90,88]})
df2=pd.DataFrame({'id':[3,4,5,6],'ml_marks':[99,88,66,55]})
df2
# Out:
#    id  ml_marks
# 0   3        99
# 1   4        88
# 2   5        66
# 3   6        55

# %%
df1.merge(df2,on='id',how='right')
# Out:
#    id  start_marks  ml_marks
# 0   3         90.0        99
# 1   4         88.0        88
# 2   5          NaN        66
# 3   6          NaN        55

# %%
df1.merge(df2,on='id') #how= inner,outer,right,left
# Out:
#    id  start_marks  ml_marks
# 0   3           90        99
# 1   4           88        88

# %%
df3=pd.concat([df1,df2]) #is means union

# %%
df1.join(df2)
# Out:
#    id  start_marks  sno  ml_marks
# 0   1           98    3        99
# 1   2           81    4        88
# 2   3           90    5        66
# 3   4           88    6        55

# %%
df3.reset_index()
# Out:
#    index  id  start_marks  ml_marks
# 0      0   1         98.0       NaN
# 1      1   2         81.0       NaN
# 2      2   3         90.0       NaN
# 3      3   4         88.0       NaN
# 4      0   3          NaN      99.0
# 5      1   4          NaN      88.0
# 6      2   5          NaN      66.0
# 7      3   6          NaN      55.0

# %%
df3.reset_index()
# Out:
#    index  id  start_marks  ml_marks
# 0      0   1         98.0       NaN
# 1      1   2         81.0       NaN
# 2      2   3         90.0       NaN
# 3      3   4         88.0       NaN
# 4      0   3          NaN      99.0
# 5      1   4          NaN      88.0
# 6      2   5          NaN      66.0
# 7      3   6          NaN      55.0

# %%
df3.reset_index(drop=True)
# Out:
#    id  start_marks  ml_marks
# 0   1         98.0       NaN
# 1   2         81.0       NaN
# 2   3         90.0       NaN
# 3   4         88.0       NaN
# 4   3          NaN      99.0
# 5   4          NaN      88.0
# 6   5          NaN      66.0
# 7   6          NaN      55.0

# %%
df3.reset_index(drop=True,inplace=True)

# %%
df3
# Out:
#    id  start_marks  ml_marks
# 0   1         98.0       NaN
# 1   2         81.0       NaN
# 2   3         90.0       NaN
# 3   4         88.0       NaN
# 4   3          NaN      99.0
# 5   4          NaN      88.0
# 6   5          NaN      66.0
# 7   6          NaN      55.0

# %%
re=pd.read_csv('Auto.csv')
re.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
